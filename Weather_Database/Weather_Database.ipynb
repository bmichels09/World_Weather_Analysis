# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Processing Record 1 | mys shmidta
# City not found. Skipping...
# Processing Record 2 | avarua
# Processing Record 3 | prince rupert
# Processing Record 4 | atuona
# Processing Record 5 | qaanaaq
# Processing Record 6 | arraial do cabo
# Processing Record 7 | cape town
# Processing Record 8 | saint-philippe
# Processing Record 9 | katsuura
# Processing Record 10 | vares
# Processing Record 11 | rikitea
# Processing Record 12 | taolanaro
# City not found. Skipping...
# Processing Record 13 | fare
# Processing Record 14 | lebu
# Processing Record 15 | poum
# Processing Record 16 | sturgis
# Processing Record 17 | port lincoln
# Processing Record 18 | ushuaia
# Processing Record 19 | amderma
# City not found. Skipping...
# Processing Record 20 | conceicao da barra
# Processing Record 21 | rockhampton
# Processing Record 22 | punta arenas
# Processing Record 23 | hithadhoo
# Processing Record 24 | xining
# Processing Record 25 | ketchikan
# Processing Record 26 | narsaq
# Processing Record 27 | san cristobal
# Processing Record 28 | vostok
# Processing Record 29 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 | jamestown
# Processing Record 31 | lagoa
# Processing Record 32 | barentsburg
# City not found. Skipping...
# Processing Record 33 | east london
# Processing Record 34 | mataura
# Processing Record 35 | albany
# Processing Record 36 | victoria
# Processing Record 37 | acapulco
# Processing Record 38 | nemuro
# Processing Record 39 | paciran
# Processing Record 40 | isangel
# Processing Record 41 | sorland
# Processing Record 42 | tuktoyaktuk
# Processing Record 43 | leningradskiy
# Processing Record 44 | nkhotakota
# Processing Record 45 | yulara
# Processing Record 46 | banda aceh
# Processing Record 47 | rohatyn
# Processing Record 48 | barrow
# Processing Record 49 | saldanha
# Processing Record 50 | hofn
# Processing Record 51 | arman
# Processing Record 52 | nanortalik
# Processing Record 53 | sakakah
# Processing Record 54 | yamada
# Processing Record 55 | eureka
# Processing Record 56 | thompson
# Processing Record 57 | lao cai
# Processing Record 58 | belushya guba
# City not found. Skipping...
# Processing Record 59 | tezu
# Processing Record 60 | lowestoft
# Processing Record 61 | puerto ayora
# Processing Record 62 | tazovskiy
# Processing Record 63 | laguna
# Processing Record 64 | nueva gerona
# Processing Record 65 | santa isabel do rio negro
# Processing Record 66 | ponta do sol
# Processing Record 67 | acari
# Processing Record 68 | barra da estiva
# Processing Record 69 | tuatapere
# Processing Record 70 | longyearbyen
# Processing Record 71 | sentyabrskiy
# City not found. Skipping...
# Processing Record 72 | upernavik
# Processing Record 73 | busselton
# Processing Record 74 | kuytun
# Processing Record 75 | bambous virieux
# Processing Record 76 | mitu
# Processing Record 77 | butaritari
# Processing Record 78 | cabo san lucas
# Processing Record 79 | oranjemund
# Processing Record 80 | clyde river
# Processing Record 81 | bredasdorp
# Processing Record 82 | bac lieu
# Processing Record 83 | geraldton
# Processing Record 84 | port elizabeth
# Processing Record 85 | praia da vitoria
# Processing Record 86 | khandbari
# Processing Record 87 | indramayu
# Processing Record 88 | mar del plata
# Processing Record 89 | lexington
# Processing Record 90 | te anau
# Processing Record 91 | bluff
# Processing Record 92 | khatanga
# Processing Record 93 | ankara
# Processing Record 94 | kodiak
# Processing Record 95 | eregli
# Processing Record 96 | rio gallegos
# Processing Record 97 | los llanos de aridane
# Processing Record 98 | bengkulu
# Processing Record 99 | el balyana
# City not found. Skipping...
# Processing Record 100 | aklavik
# Processing Record 101 | keti bandar
# Processing Record 102 | broome
# Processing Record 103 | bethel
# Processing Record 104 | nhulunbuy
# Processing Record 105 | talnakh
# Processing Record 106 | ludvika
# Processing Record 107 | kieta
# Processing Record 108 | dong hoi
# Processing Record 109 | port-gentil
# Processing Record 110 | darfo
# Processing Record 111 | hilo
# Processing Record 112 | mahajanga
# Processing Record 113 | yellowknife
# Processing Record 114 | lavrentiya
# Processing Record 115 | haines junction
# Processing Record 116 | severo-kurilsk
# Processing Record 117 | kamenka
# Processing Record 118 | tasiilaq
# Processing Record 119 | warri
# Processing Record 120 | tsihombe
# City not found. Skipping...
# Processing Record 121 | haizhou
# Processing Record 122 | port alfred
# Processing Record 123 | hermanus
# Processing Record 124 | terney
# Processing Record 125 | saint george
# Processing Record 126 | new norfolk
# Processing Record 127 | ribeira grande
# Processing Record 128 | chokurdakh
# Processing Record 129 | acarau
# Processing Record 130 | vaitupu
# City not found. Skipping...
# Processing Record 131 | hobart
# Processing Record 132 | ust-nera
# Processing Record 133 | nikolskoye
# Processing Record 134 | airai
# Processing Record 135 | karla
# Processing Record 136 | hualmay
# Processing Record 137 | nizhneyansk
# City not found. Skipping...
# Processing Record 138 | mwinilunga
# Processing Record 139 | coolum beach
# Processing Record 140 | kapaa
# Processing Record 141 | castro
# Processing Record 142 | karabanovo
# Processing Record 143 | buraydah
# Processing Record 144 | dunmore east
# Processing Record 145 | wanxian
# Processing Record 146 | vaini
# Processing Record 147 | mackay
# Processing Record 148 | teya
# Processing Record 149 | kargasok
# Processing Record 150 | ancud
# Processing Record 151 | saravan
# Processing Record 152 | artyk
# City not found. Skipping...
# Processing Record 153 | bathsheba
# Processing Record 154 | andenes
# Processing Record 155 | khasan
# Processing Record 156 | ramsar
# Processing Record 157 | tual
# Processing Record 158 | talcahuano
# Processing Record 159 | rungata
# City not found. Skipping...
# Processing Record 160 | esperance
# Processing Record 161 | gillette
# Processing Record 162 | mahebourg
# Processing Record 163 | saleaula
# City not found. Skipping...
# Processing Record 164 | nome
# Processing Record 165 | sana
# Processing Record 166 | saskylakh
# Processing Record 167 | miraflores
# Processing Record 168 | mapimi
# Processing Record 169 | sitka
# Processing Record 170 | aksarka
# Processing Record 171 | paradwip
# City not found. Skipping...
# Processing Record 172 | carnarvon
# Processing Record 173 | nouadhibou
# Processing Record 174 | souillac
# Processing Record 175 | dikson
# Processing Record 176 | anadyr
# Processing Record 177 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 178 | najran
# Processing Record 179 | gobabis
# Processing Record 180 | constitucion
# Processing Record 181 | sayaxche
# Processing Record 182 | kailua
# Processing Record 183 | vila franca do campo
# Processing Record 184 | guisa
# Processing Record 185 | tabiauea
# City not found. Skipping...
# Processing Record 186 | kolyvan
# Processing Record 187 | launceston
# Processing Record 188 | pevek
# Processing Record 189 | saint-leu
# Processing Record 190 | codrington
# Processing Record 191 | georgetown
# Processing Record 192 | tocopilla
# Processing Record 193 | zaranj
# Processing Record 194 | aasiaat
# Processing Record 195 | tiksi
# Processing Record 196 | grand centre
# City not found. Skipping...
# Processing Record 197 | talen
# Processing Record 198 | jand
# Processing Record 199 | agva
# City not found. Skipping...
# Processing Record 200 | hobyo
# Processing Record 201 | honiara
# Processing Record 202 | alekseyevsk
# Processing Record 203 | ngukurr
# City not found. Skipping...
# Processing Record 204 | maturin
# Processing Record 205 | atambua
# Processing Record 206 | saint-marc-des-carrieres
# Processing Record 207 | noumea
# Processing Record 208 | iqaluit
# Processing Record 209 | rawannawi
# City not found. Skipping...
# Processing Record 210 | tarko-sale
# Processing Record 211 | sinkat
# City not found. Skipping...
# Processing Record 212 | asau
# Processing Record 213 | bukachacha
# Processing Record 214 | samusu
# City not found. Skipping...
# Processing Record 215 | batticaloa
# Processing Record 216 | sola
# Processing Record 217 | northam
# Processing Record 218 | osorno
# Processing Record 219 | solsvik
# City not found. Skipping...
# Processing Record 220 | hanzhong
# Processing Record 221 | faanui
# Processing Record 222 | roald
# Processing Record 223 | qeshm
# Processing Record 224 | boundiali
# Processing Record 225 | ipixuna
# Processing Record 226 | warqla
# City not found. Skipping...
# Processing Record 227 | chara
# Processing Record 228 | grand river south east
# City not found. Skipping...
# Processing Record 229 | bandarbeyla
# Processing Record 230 | beringovskiy
# Processing Record 231 | boddam
# Processing Record 232 | altay
# Processing Record 233 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 234 | nantucket
# Processing Record 235 | fortuna
# Processing Record 236 | alice
# Processing Record 237 | berlevag
# Processing Record 238 | dzhusaly
# City not found. Skipping...
# Processing Record 239 | bauta
# Processing Record 240 | kralendijk
# Processing Record 241 | moctezuma
# Processing Record 242 | termoli
# Processing Record 243 | richards bay
# Processing Record 244 | homer
# Processing Record 245 | ilhabela
# Processing Record 246 | alacranes
# Processing Record 247 | caravelas
# Processing Record 248 | bubaque
# Processing Record 249 | chuy
# Processing Record 250 | mount darwin
# Processing Record 251 | puri
# Processing Record 252 | port-cartier
# Processing Record 253 | necochea
# Processing Record 254 | kavaratti
# Processing Record 255 | aswan
# Processing Record 256 | phan thiet
# Processing Record 257 | kruisfontein
# Processing Record 258 | edson
# Processing Record 259 | ilulissat
# Processing Record 260 | san patricio
# Processing Record 261 | norman wells
# Processing Record 262 | dien bien
# City not found. Skipping...
# Processing Record 263 | kalakamati
# Processing Record 264 | le robert
# Processing Record 265 | vao
# Processing Record 266 | beyneu
# Processing Record 267 | cherskiy
# Processing Record 268 | buzmeyin
# Processing Record 269 | sao miguel do araguaia
# Processing Record 270 | plaster rock
# Processing Record 271 | finote selam
# Processing Record 272 | santa paula
# Processing Record 273 | hasaki
# Processing Record 274 | shingu
# Processing Record 275 | balasheyka
# Processing Record 276 | umzimvubu
# City not found. Skipping...
# Processing Record 277 | karratha
# Processing Record 278 | san carlos
# Processing Record 279 | mandalgovi
# Processing Record 280 | tubuala
# Processing Record 281 | okulovka
# Processing Record 282 | kampene
# Processing Record 283 | hurricane
# Processing Record 284 | batagay-alyta
# Processing Record 285 | saint-pierre
# Processing Record 286 | bang saphan
# Processing Record 287 | awbari
# Processing Record 288 | fort nelson
# Processing Record 289 | biak
# Processing Record 290 | burnie
# Processing Record 291 | bud
# Processing Record 292 | namatanai
# Processing Record 293 | luwuk
# Processing Record 294 | huangchuan
# Processing Record 295 | mocambique
# City not found. Skipping...
# Processing Record 296 | ivanivka
# Processing Record 297 | ballina
# Processing Record 298 | champerico
# Processing Record 299 | sao joao da barra
# Processing Record 300 | lakatoro
# Processing Record 301 | bolungarvik
# City not found. Skipping...
# Processing Record 302 | torbay
# Processing Record 303 | lolodorf
# Processing Record 304 | cidreira
# Processing Record 305 | aparecida do taboado
# Processing Record 306 | husavik
# Processing Record 307 | kaohsiung
# Processing Record 308 | wilmington
# Processing Record 309 | mudgee
# Processing Record 310 | kushima
# Processing Record 311 | mogadishu
# Processing Record 312 | inuvik
# Processing Record 313 | qinhuangdao
# Processing Record 314 | weligama
# Processing Record 315 | toamasina
# Processing Record 316 | miami
# Processing Record 317 | laharpur
# Processing Record 318 | sorvag
# City not found. Skipping...
# Processing Record 319 | asyut
# Processing Record 320 | ixtapa
# Processing Record 321 | taltal
# Processing Record 322 | kazalinsk
# City not found. Skipping...
# Processing Record 323 | faya
# Processing Record 324 | dinan
# Processing Record 325 | troitskoye
# Processing Record 326 | pimentel
# Processing Record 327 | drummondville
# Processing Record 328 | mahon
# Processing Record 329 | klaksvik
# Processing Record 330 | alofi
# Processing Record 331 | sakyla
# Processing Record 332 | yumen
# Processing Record 333 | ornskoldsvik
# Processing Record 334 | lasa
# Processing Record 335 | abha
# Processing Record 336 | vangaindrano
# Processing Record 337 | tarnos
# Processing Record 338 | mecca
# Processing Record 339 | hambantota
# Processing Record 340 | mount isa
# Processing Record 341 | bata
# Processing Record 342 | huarmey
# Processing Record 343 | vanavara
# Processing Record 344 | port blair
# Processing Record 345 | visnes
# Processing Record 346 | martapura
# Processing Record 347 | marv dasht
# City not found. Skipping...
# Processing Record 348 | srednekolymsk
# Processing Record 349 | padang
# Processing Record 350 | dabola
# Processing Record 351 | vallenar
# Processing Record 352 | biltine
# Processing Record 353 | krasnoselkup
# Processing Record 354 | alice springs
# Processing Record 355 | marcona
# City not found. Skipping...
# Processing Record 356 | rocha
# Processing Record 357 | flinders
# Processing Record 358 | flagstaff
# Processing Record 359 | banff
# Processing Record 360 | atikokan
# Processing Record 361 | liverpool
# Processing Record 362 | itoman
# Processing Record 363 | provideniya
# Processing Record 364 | milingimbi
# City not found. Skipping...
# Processing Record 365 | celestun
# Processing Record 366 | san pedro del parana
# Processing Record 367 | zhigansk
# Processing Record 368 | attawapiskat
# City not found. Skipping...
# Processing Record 369 | quelimane
# Processing Record 370 | gat
# Processing Record 371 | teresina
# Processing Record 372 | grindavik
# Processing Record 373 | kununurra
# Processing Record 374 | hami
# Processing Record 375 | cayenne
# Processing Record 376 | zyryanka
# Processing Record 377 | san quintin
# Processing Record 378 | portland
# Processing Record 379 | palmer
# Processing Record 380 | kaitangata
# Processing Record 381 | kumluca
# Processing Record 382 | whithorn
# Processing Record 383 | estelle
# Processing Record 384 | erdenet
# Processing Record 385 | katobu
# Processing Record 386 | sechura
# Processing Record 387 | batagay
# Processing Record 388 | honningsvag
# Processing Record 389 | leshukonskoye
# Processing Record 390 | fort myers beach
# Processing Record 391 | itaituba
# Processing Record 392 | shimoda
# Processing Record 393 | evensk
# Processing Record 394 | guozhen
# Processing Record 395 | tiarei
# Processing Record 396 | singapore
# Processing Record 397 | coquimbo
# Processing Record 398 | kavieng
# Processing Record 399 | puerto baquerizo moreno
# Processing Record 400 | tunceli
# Processing Record 401 | waipawa
# Processing Record 402 | wanlaweyn
# Processing Record 403 | puerto carreno
# Processing Record 404 | rawson
# Processing Record 405 | hokitika
# Processing Record 406 | tete
# Processing Record 407 | rochegda
# Processing Record 408 | ruteng
# Processing Record 409 | new glasgow
# Processing Record 410 | killini
# City not found. Skipping...
# Processing Record 411 | altamont
# Processing Record 412 | mayo
# Processing Record 413 | cap malheureux
# Processing Record 414 | ijero
# Processing Record 415 | dianopolis
# City not found. Skipping...
# Processing Record 416 | san pedro
# Processing Record 417 | esso
# Processing Record 418 | athabasca
# Processing Record 419 | yamaranguila
# Processing Record 420 | hamilton
# Processing Record 421 | loiza
# Processing Record 422 | west bay
# Processing Record 423 | phan rang
# City not found. Skipping...
# Processing Record 424 | letnyaya stavka
# Processing Record 425 | sinnamary
# Processing Record 426 | timra
# Processing Record 427 | kasangulu
# Processing Record 428 | margate
# Processing Record 429 | satitoa
# City not found. Skipping...
# Processing Record 430 | sur
# Processing Record 431 | sonoita
# Processing Record 432 | opuwo
# Processing Record 433 | novyy urgal
# Processing Record 434 | bonavista
# Processing Record 435 | alyangula
# Processing Record 436 | razdolinsk
# Processing Record 437 | sinop
# Processing Record 438 | kresna
# Processing Record 439 | gbarnga
# Processing Record 440 | viligili
# City not found. Skipping...
# Processing Record 441 | letlhakane
# Processing Record 442 | skalistyy
# City not found. Skipping...
# Processing Record 443 | dzemul
# Processing Record 444 | tambura
# Processing Record 445 | batemans bay
# Processing Record 446 | kaeo
# Processing Record 447 | pedasi
# Processing Record 448 | vagay
# Processing Record 449 | hare bay
# Processing Record 450 | okhotsk
# Processing Record 451 | kahului
# Processing Record 452 | zhob
# Processing Record 453 | belmonte
# Processing Record 454 | wulanhaote
# City not found. Skipping...
# Processing Record 455 | sierra vista
# Processing Record 456 | luderitz
# Processing Record 457 | conakry
# Processing Record 458 | daru
# Processing Record 459 | rorvik
# Processing Record 460 | college
# Processing Record 461 | thabazimbi
# Processing Record 462 | briancon
# Processing Record 463 | khash
# Processing Record 464 | komsomolskiy
# Processing Record 465 | ushtobe
# Processing Record 466 | samana
# Processing Record 467 | bajah
# Processing Record 468 | sambava
# Processing Record 469 | karuzi
# Processing Record 470 | ostrovnoy
# Processing Record 471 | reconquista
# Processing Record 472 | puerto quijarro
# Processing Record 473 | novikovo
# Processing Record 474 | igarka
# Processing Record 475 | nishihara
# Processing Record 476 | bilibino
# Processing Record 477 | havre-saint-pierre
# Processing Record 478 | erenhot
# Processing Record 479 | parry sound
# Processing Record 480 | sioux lookout
# Processing Record 481 | panjab
# Processing Record 482 | tateyama
# Processing Record 483 | urumqi
# Processing Record 484 | iringa
# Processing Record 485 | nador
# Processing Record 486 | moose factory
# Processing Record 487 | krotovka
# Processing Record 488 | riyadh
# Processing Record 489 | yerbogachen
# Processing Record 490 | yatou
# Processing Record 491 | chardara
# Processing Record 492 | karaul
# City not found. Skipping...
# Processing Record 493 | sao filipe
# Processing Record 494 | upata
# Processing Record 495 | manaure
# Processing Record 496 | lolua
# City not found. Skipping...
# Processing Record 497 | belyy yar
# Processing Record 498 | lyubim
# Processing Record 499 | ahipara
# Processing Record 500 | palabuhanratu
# City not found. Skipping...
# Processing Record 501 | kutum
# Processing Record 502 | lima
# Processing Record 503 | butembo
# Processing Record 504 | ust-tsilma
# Processing Record 505 | bowen
# Processing Record 506 | katherine
# Processing Record 507 | leh
# Processing Record 508 | camocim
# Processing Record 509 | tacuarembo
# Processing Record 510 | abdulino
# Processing Record 511 | osa
# Processing Record 512 | saint-ambroise
# Processing Record 513 | kyabe
# Processing Record 514 | arona
# Processing Record 515 | erdaojiang
# Processing Record 516 | hovd
# Processing Record 517 | acapetahua
# Processing Record 518 | koboldo
# City not found. Skipping...
# Processing Record 519 | moree
# Processing Record 520 | north bend
# Processing Record 521 | namibe
# Processing Record 522 | denpasar
# Processing Record 523 | ambilobe
# Processing Record 524 | san miguel
# Processing Record 525 | kaduqli
# Processing Record 526 | camana
# Processing Record 527 | bur gabo
# City not found. Skipping...
# Processing Record 528 | nueve de julio
# Processing Record 529 | pandan
# Processing Record 530 | taunggyi
# Processing Record 531 | agropoli
# Processing Record 532 | chulman
# Processing Record 533 | kyren
# Processing Record 534 | tinskoy
# Processing Record 535 | makakilo city
# Processing Record 536 | nam phong
# Processing Record 537 | nikel
# Processing Record 538 | nizhniy lomov
# Processing Record 539 | pyapon
# Processing Record 540 | olafsvik
# Processing Record 541 | majene
# Processing Record 542 | broceni
# Processing Record 543 | alvorada
# Processing Record 544 | kawhia
# Processing Record 545 | amapa
# Processing Record 546 | svetlogorsk
# Processing Record 547 | lompoc
# Processing Record 548 | dharmadam
# Processing Record 549 | pychas
# Processing Record 550 | mareeba
# Processing Record 551 | westport
# Processing Record 552 | jilikul
# Processing Record 553 | manggar
# Processing Record 554 | san jeronimo
# Processing Record 555 | kloulklubed
# Processing Record 556 | inirida
# Processing Record 557 | yanam
# Processing Record 558 | erkner
# Processing Record 559 | port hedland
# Processing Record 560 | cabedelo
# Processing Record 561 | aketi
# Processing Record 562 | lashio
# Processing Record 563 | marzuq
# Processing Record 564 | huicungo
# Processing Record 565 | macaboboni
# City not found. Skipping...
# Processing Record 566 | ouango
# Processing Record 567 | pangnirtung
# Processing Record 568 | puerto morazan
# Processing Record 569 | saint-augustin
# Processing Record 570 | tapaua
# City not found. Skipping...
# Processing Record 571 | sisimiut
# Processing Record 572 | verkhnevilyuysk
# Processing Record 573 | roseburg
# Processing Record 574 | lucapa
# Processing Record 575 | puerto el triunfo
# Processing Record 576 | la ronge
# Processing Record 577 | yar-sale
# Processing Record 578 | vila velha
# Processing Record 579 | yasnyy
# Processing Record 580 | turayf
# Processing Record 581 | caohai
# Processing Record 582 | brae
# Processing Record 583 | casambalangan
# Processing Record 584 | fomboni
# Processing Record 585 | pavagada
# Processing Record 586 | janauba
# Processing Record 587 | port hardy
# Processing Record 588 | karpathos
# Processing Record 589 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 590 | kankaanpaa
# Processing Record 591 | porto novo
# Processing Record 592 | barawe
# City not found. Skipping...
# Processing Record 593 | at-bashi
# Processing Record 594 | samalaeulu
# City not found. Skipping...
# Processing Record 595 | bianzhuang
# Processing Record 596 | logan lake
# Processing Record 597 | viedma
# Processing Record 598 | atar
# Processing Record 599 | dawei
# Processing Record 600 | nioki
# Processing Record 601 | liepaja
# Processing Record 602 | kedougou
# Processing Record 603 | the valley
# Processing Record 604 | micheweni
# Processing Record 605 | rio grande
# Processing Record 606 | salinas
# Processing Record 607 | trairi
# Processing Record 608 | virden
# Processing Record 609 | afrikanda
# Processing Record 610 | ruian
# City not found. Skipping...
# Processing Record 611 | touros
# Processing Record 612 | cockburn town
# Processing Record 613 | zelenoborskiy
# Processing Record 614 | asahikawa
# Processing Record 615 | bukama
# Processing Record 616 | tura
# Processing Record 617 | owando
# Processing Record 618 | ust-maya
# Processing Record 619 | tougue
# Processing Record 620 | ngaoundere
# Processing Record 621 | glenwood springs
# Processing Record 622 | pakxe
# Processing Record 623 | mattawa
# Processing Record 624 | serramanna
# Processing Record 625 | stromness
# Processing Record 626 | cullman
# Processing Record 627 | zeya
# Processing Record 628 | salalah
# Processing Record 629 | nuuk
# Processing Record 630 | liku
# Processing Record 631 | bima
# Processing Record 632 | barcelona
# Processing Record 633 | kidal
# Processing Record 634 | baherden
# Processing Record 635 | finschhafen
# Processing Record 636 | zhangjiakou
# Processing Record 637 | fraserburgh
# Processing Record 638 | wageningen
# Processing Record 639 | tumannyy
# City not found. Skipping...
# Processing Record 640 | hede
# Processing Record 641 | vardo
# Processing Record 642 | khowst
# Processing Record 643 | fairbanks
# Processing Record 644 | knysna
# Processing Record 645 | lodwar
# Processing Record 646 | vestmannaeyjar
# Processing Record 647 | akyab
# Processing Record 648 | nagar karnul
# Processing Record 649 | akdepe
# Processing Record 650 | issia
# Processing Record 651 | salto del guaira
# Processing Record 652 | araouane
# Processing Record 653 | vanimo
# Processing Record 654 | yakeshi
# Processing Record 655 | priiskovyy
# Processing Record 656 | el tocuyo
# Processing Record 657 | saint-georges
# Processing Record 658 | kamenskoye
# City not found. Skipping...
# Processing Record 659 | half moon bay
# Processing Record 660 | hirara
# Processing Record 661 | suoyarvi
# Processing Record 662 | houma
# Processing Record 663 | boguchany
# Processing Record 664 | oxford
# Processing Record 665 | tawkar
# City not found. Skipping...
# Processing Record 666 | ayan
# Processing Record 667 | saint albans
# Processing Record 668 | bilma
# Processing Record 669 | gizo
# Processing Record 670 | henties bay
# Processing Record 671 | ayorou
# Processing Record 672 | sheridan
# Processing Record 673 | voyvozh
# Processing Record 674 | urucara
# Processing Record 675 | ocos
# Processing Record 676 | tokmak
# Processing Record 677 | guilin
# Processing Record 678 | jiazi
# Processing Record 679 | kitgum
# Processing Record 680 | lerici
# Processing Record 681 | jadu
# Processing Record 682 | auka
# Processing Record 683 | qaqortoq
# Processing Record 684 | ust-karsk
# Processing Record 685 | buin
# Processing Record 686 | moa
# Processing Record 687 | alterosa
# Processing Record 688 | marivan
# Processing Record 689 | bam
# Processing Record 690 | jinka
# Processing Record 691 | sumisip
# Processing Record 692 | puerto escondido
# Processing Record 693 | cervo
# Processing Record 694 | tignere
# Processing Record 695 | parabel
# Processing Record 696 | suao
# City not found. Skipping...
# Processing Record 697 | villa oliva
# City not found. Skipping...
# Processing Record 698 | santa ana
# Processing Record 699 | taoudenni
# Processing Record 700 | umm kaddadah
# Processing Record 701 | kutno
# Processing Record 702 | port keats
# Processing Record 703 | aguas vermelhas
# Processing Record 704 | mergui
# City not found. Skipping...
# Processing Record 705 | oriximina
# Processing Record 706 | coahuayana
# Processing Record 707 | tuscaloosa
# Processing Record 708 | jiamusi
# Processing Record 709 | mezen
# Processing Record 710 | dosso
# Processing Record 711 | dunedin
# Processing Record 712 | rivera
# Processing Record 713 | uyo
# Processing Record 714 | surgut
# Processing Record 715 | mayumba
# Processing Record 716 | mukhen
# Processing Record 717 | greymouth
# Processing Record 718 | wanning
# Processing Record 719 | pochutla
# Processing Record 720 | grand-santi
# Processing Record 721 | ouadda
# Processing Record 722 | udachnyy
# Processing Record 723 | bara
# Processing Record 724 | taian
# Processing Record 725 | sakaiminato
# Processing Record 726 | nahrin
# Processing Record 727 | moirang
# Processing Record 728 | manuk mangkaw
# Processing Record 729 | quatre cocos
# Processing Record 730 | camacha
# Processing Record 731 | navirai
# Processing Record 732 | manawar
# Processing Record 733 | labutta
# City not found. Skipping...
# Processing Record 734 | halifax
# Processing Record 735 | dormidontovka
# Processing Record 736 | kirensk
# Processing Record 737 | santa cruz
# Processing Record 738 | ambon
# Processing Record 739 | minab
# Processing Record 740 | mbini
# Processing Record 741 | sarangani

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Avarua      CK -21.2078 -159.7750     77.00        78          90
# 1    Prince Rupert      CA  54.3161 -130.3201     50.00        71          20
# 2           Atuona      PF  -9.8000 -139.0333     80.42        78          96
# 3          Qaanaaq      GL  77.4840  -69.3632     25.14        61          97
# 4  Arraial Do Cabo      BR -22.9661  -42.0278     71.71        75          75
# 5        Cape Town      ZA -33.9258   18.4232     64.00        66           0
# 6   Saint-Philippe      RE -21.3585   55.7679     75.20        69           0
# 7         Katsuura      JP  35.1333  140.3000     69.01        78          17
# 8            Vares      BA  44.1644   18.3283     51.80        93          75
# 9          Rikitea      PF -23.1203 -134.9692     77.79        80          29
#
#    Wind Speed Current Description
# 0       10.36          light rain
# 1        4.61          few clouds
# 2       14.32     overcast clouds
# 3        5.93     overcast clouds
# 4        6.13       broken clouds
# 5        3.44           clear sky
# 6        6.91           clear sky
# 7       15.99          few clouds
# 8        1.14       broken clouds
# 9       12.12    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
